# %% [markdown]
# <a href="https://colab.research.google.com/github/yuj0630/Catholic_Regacy/blob/main/apart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
pip install PublicDataReader --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.3 MB 6.8 MB/s
# ...

# %%
import PublicDataReader as pdr
print(pdr.__version__)
# Out:
# 1.0.6

# %%
# 2.공공 데이터 포털 OpenAPI 인증키 입력하기
serviceKey = "RIAUQmjzO9F%2BbEEVKESgWpfreLLdJfCtqpazkDG2y6I4OIxVwPCPI1oGN8tcxHuHSMgWDyOq%2F2a25odOmHiY0g%3D%3D"

# 3. 국토교통부 실거래가 정보 조회 API 섹션 정의하기
ts = pdr.Transaction(serviceKey, debug=True)
# Out:
# [INFO] 아파트 매매 조회 서비스 정상 - (00) NORMAL SERVICE.
# INFO:root:아파트 매매 조회 서비스 정상 - (00) NORMAL SERVICE.
# [ERROR] 아파트 전월세 조회 서비스 오류 - (99) SERVICE ACCESS DENIED ERROR.
# ERROR:root:아파트 전월세 조회 서비스 오류 - (99) SERVICE ACCESS DENIED ERROR.
# [ERROR] 오피스텔 매매 조회 서비스 오류 - (99) SERVICE ACCESS DENIED ERROR.
# ERROR:root:오피스텔 매매 조회 서비스 오류 - (99) SERVICE ACCESS DENIED ERROR.
# [ERROR] 오피스텔 전월세 조회 서비스 오류 - (99) SERVICE ACCESS DENIED ERROR.
# ERROR:root:오피스텔 전월세 조회 서비스 오류 - (99) SERVICE ACCESS DENIED ERROR.
# [ERROR] 단독다가구 매매 조회 서비스 오류 - (99) SERVICE ACCESS DENIED ERROR.
# ERROR:root:단독다가구 매매 조회 서비스 오류 - (99) SERVICE ACCESS DENIED ERROR.
# [ERROR] 단독다가구 전월세 조회 서비스 오류 - (99) SERVICE ACCESS DENIED ERROR.
# ERROR:root:단독다가구 전월세 조회 서비스 오류 - (99) SERVICE ACCESS DENIED ERROR.
# [ERROR] 연립다세대 매매 조회 서비스 오류 - (99) SERVICE ACCESS DENIED ERROR.
# ERROR:root:연립다세대 매매 조회 서비스 오류 - (99) SERVICE ACCESS DENIED ERROR.
# [ERROR] 연립다세대 전월세 조회 서비스 오류 - (99) SERVICE ACCESS DENIED ERROR.
# ...

# %%
# 4. 지역코드(시군구코드) 검색하기
sigunguName = "분당구"
code = pdr.code_bdong()
code.loc[(code['시군구명'].str.contains(sigunguName, no=False)) &
         (code['읍면동명'].isna())]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-858ad2b7fe51> in <module>
#       2 sigunguName = "분당구"
#       3 code = pdr.code_bdong()
# ----> 4 code.loc[(code['시군구명'].str.contains(sigunguName, no=False)) &
#       5          (code['읍면동명'].isna())]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#     114                 )
#     115                 raise TypeError(msg)
# --> 116             return func(self, *args, **kwargs)
#     117
#     118         wrapper.__name__ = func_name
#
# TypeError: contains() got an unexpected keyword argument 'no'

# %%
# 5. 지역, 월 별 데이터프레임 만들기
prod="아파트"
trans="매매"
sigunguCode="41135"
YearMonth="202101"

df = ts.read_data(prod, trans, sigunguCode, YearMonth)
df
# Out:
#       지역코드       도로명  법정동   지번           아파트  건축년도   층     전용면적     년  월  ...  \
# 0    41135       수내로  분당동   38      샛별마을(우방)  1994   8   84.990  2021  1  ...
# 1    41135       수내로  분당동   38      샛별마을(우방)  1994   4   84.990  2021  1  ...
# 2    41135   장안로41번길  분당동   66      장안타운(건영)  1993  17  162.850  2021  1  ...
# 3    41135       분당로  분당동   34     샛별마을(라이프)  1992   6  126.415  2021  1  ...
# 4    41135       수내로  분당동   39      샛별마을(삼부)  1992   6   69.960  2021  1  ...
# ..     ...       ...  ...  ...           ...   ...  ..      ...   ... ..  ...
# 370  41135  판교원로82번길  운중동  918  산운마을13단지(태영)  2010  18  101.650  2021  1  ...
# 371  41135  판교원로82번길  운중동  918  산운마을13단지(태영)  2010  30  101.670  2021  1  ...
# 372  41135  판교원로82번길  운중동  918  산운마을13단지(태영)  2010  24  101.670  2021  1  ...
# 373  41135      판교원로  운중동  922  산운마을11단지(주공)  2009   1   59.840  2021  1  ...
# 374  41135      판교원로  운중동  922  산운마을11단지(주공)  2009   7   59.840  2021  1  ...
#
# ...

# %%
df.to_excel('result_202110.xlsx')

# %%
# 6. 지역, 기간 별 데이터프레임 만들기
prod="아파트"
trans="매매"
sigunguCode="41135"
startYearMonth="202101"
endYearMonth="202111"

df = ts.collect_data(prod, trans, sigunguCode, startYearMonth, endYearMonth)
df
# Out:
# [INFO] 아파트 매매 202101 조회 시작
# INFO:root:아파트 매매 202101 조회 시작
# [INFO] 아파트 매매 202102 조회 시작
# INFO:root:아파트 매매 202102 조회 시작
# [INFO] 아파트 매매 202103 조회 시작
# INFO:root:아파트 매매 202103 조회 시작
# [INFO] 아파트 매매 202104 조회 시작
# INFO:root:아파트 매매 202104 조회 시작
# [INFO] 아파트 매매 202105 조회 시작
# INFO:root:아파트 매매 202105 조회 시작
# [INFO] 아파트 매매 202106 조회 시작
# INFO:root:아파트 매매 202106 조회 시작
# [INFO] 아파트 매매 202107 조회 시작
# INFO:root:아파트 매매 202107 조회 시작
# [INFO] 아파트 매매 202108 조회 시작
# INFO:root:아파트 매매 202108 조회 시작
# [INFO] 아파트 매매 202109 조회 시작
# INFO:root:아파트 매매 202109 조회 시작
# [INFO] 아파트 매매 202110 조회 시작
# INFO:root:아파트 매매 202110 조회 시작
# [INFO] 아파트 매매 202111 조회 시작
# INFO:root:아파트 매매 202111 조회 시작
#        지역코드       도로명  법정동       지번               아파트  건축년도   층      전용면적  \
# 0     41135       수내로  분당동       38          샛별마을(우방)  1994   8   84.9900
# 1     41135       수내로  분당동       38          샛별마을(우방)  1994   4   84.9900
# 2     41135   장안로41번길  분당동       66          장안타운(건영)  1993  17  162.8500
# ...

# %%
df.to_excel('result_202110.xlsx')
